# %%
import numpy as np 
np.random.seed(0)
import seaborn as sns
flights= sns.load_dataset("flights")
flights_pivot = flights.pivot(index="month", columns="year",  values="passengers")
heat_map_4=sns.heatmap(flights_pivot)

# %%
flights= sns.load_dataset("flights")
sns.regplot(x="passengers",y="year",data = flights)
# Out:
# <Axes: xlabel='passengers', ylabel='year'>

# %%
from scipy import stats
flights=sns.load_dataset("flights")
print(flights)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
person_correlation = stats.pearsonr(flights['year'],flights['passengers'])
print(person_correlation)
# Out:
# PearsonRResult(statistic=np.float64(0.9218238352924201), pvalue=np.float64(2.581042551911042e-60))

# %%
#simple linear regression
from sklearn.linear_model import LinearRegression
